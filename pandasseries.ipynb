# %%
import pandas as pd
import numpy as np

# %%
l=[23,23,2333,266]
m={
    1:23,
    2:33,
    8:233
}
print(pd.Series(l))#S should be captial
print(pd.Series(m))
# Out:
# 0      23
# 1      23
# 2    2333
# 3     266
# dtype: int64
# 1     23
# 2     33
# 8    233
# dtype: int64

# %%
l=[23,23,2333,266]
p=[278,20,233,260]
pd.Series(l,index=p)
# Out:
# 278      23
# 20       23
# 233    2333
# 260     266
# dtype: int64

# %%
# pd.short(l)
n=pd.Series(l,index=p,name="given data")

# %%
n.size
n.name
n.is_unique
n.index
n.values
# Out:
# array([  23,   23, 2333,  266])

# %%
n.max()
# Out:
# np.int64(2333)

# %%
print(n.min())
print(n.sum())
print(n.prod())
print(n.mean())
print(n.std())
print(n.var())
print(n.median())
print(n.mode())
# Out:
# 23
# 2645
# 328285762
# 661.25
# 1120.371478573067
# 1255232.25
# 144.5
# 0    23
# Name: given data, dtype: int64

# %%
print(n.sort_values())
print(n.sort_index())
print(n.sort_values(ascending=False))
# Out:
# 278      23
# 20       23
# 260     266
# 233    2333
# Name: given data, dtype: int64
# 20       23
# 233    2333
# 260     266
# 278      23
# Name: given data, dtype: int64
# 233    2333
# 260     266
# 278      23
# 20       23
# Name: given data, dtype: int64

# %%
# a=pd.read_csv("iris.csv",squeeze=True)
a=pd.read_csv("iris.csv")
type(a['sepal_length'])
a_s=a.squeeze()

# %%
a_s.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
a_s.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
a_s.shape
# Out:
# (150, 5)

# %%
a_s.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
# a.is_unique()
# a.unique()

# %%
a_s.value_counts()
a_s.sort_values(by="sepal_length")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
a_s.sort_values(by='sepal_width',ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 15            5.7          4.4           1.5          0.4      setosa
# 33            5.5          4.2           1.4          0.2      setosa
# 32            5.2          4.1           1.5          0.1      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 16            5.4          3.9           1.3          0.4      setosa
# ..            ...          ...           ...          ...         ...
# 87            6.3          2.3           4.4          1.3  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 60            5.0          2.0           3.5          1.0  versicolor
#
# [150 rows x 5 columns]

# %%
a_s.sort_values(by='sepal_width',inplace=True)

# %%
a_s
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 60            5.0          2.0           3.5          1.0  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 41            4.5          2.3           1.3          0.3      setosa
# ..            ...          ...           ...          ...         ...
# 16            5.4          3.9           1.3          0.4      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 32            5.2          4.1           1.5          0.1      setosa
# 33            5.5          4.2           1.4          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
#
# [150 rows x 5 columns]

# %%
a_s.sort_index(inplace=True,ascending=False)

# %%
a_s
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 149           5.9          3.0           5.1          1.8  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 4             5.0          3.6           1.4          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 0             5.1          3.5           1.4          0.2     setosa
#
# [150 rows x 5 columns]

# %%
a_s.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#INDEXING
z=[12,34,7,9,90,89,55,78]
z[0]
# Out:
# 12

# %%
z[-1]
z[2:]
a_s[[2,3]]#fancy indexing
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 3
#       1 z[-1]
#       2 z[2:]
# ----> 3 a_s[[2,3]]#fancy indexing
#
# File /opt/anaconda3/envs/pytorch_m1/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/pytorch_m1/lib/python3.10/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
# ...

# %%
n[278]
# Out:
# np.int64(23)

# %%
n[278]=100

# %%
n
# Out:
# 278     100
# 20       23
# 233    2333
# 260     266
# Name: given data, dtype: int64

# %%
n[230]=200

# %%
n
# Out:
# 278     100
# 20       23
# 233    2333
# 260     266
# 230     200
# Name: given data, dtype: int64

# %%
len(n)
dir(n)
type(n)
sorted(n)
# Out:
# [23, 100, 200, 266, 2333]

# %%
list(n)
# Out:
# [100, 23, 2333, 266, 200]

# %%
dict(n)
# Out:
# {278: np.int64(100),
#  20: np.int64(23),
#  233: np.int64(2333),
#  260: np.int64(266),
#  230: np.int64(200)}

# %%
278 in n
# Out:
# True

# %%
100 not in n
# Out:
# True

# %%
for i in n.values:
    print(i)
# Out:
# 100
# 23
# 2333
# 266
# 200

# %%
100-n
# Out:
# 278       0
# 20       77
# 233   -2233
# 260    -166
# 230    -100
# Name: given data, dtype: int64

# %%
n>=50
# Out:
# 278     True
# 20     False
# 233     True
# 260     True
# 230     True
# Name: given data, dtype: bool

# %%
n[n>=50]
# Out:
# 278     100
# 233    2333
# 260     266
# 230     200
# Name: given data, dtype: int64

# %%
n[n>=50].size
# Out:
# 4

# %%
n.plot()
# Out:
# <Axes: >

# %%
n.plot(kind=bar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 n.plot(kind=bar)
#
# NameError: name 'bar' is not defined
