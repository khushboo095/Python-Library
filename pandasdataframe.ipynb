# %%
import pandas as pd
import numpy as np

# %%
student=[

    [100,23,45,67,0],
    [50,44,34,56,78],
    [34,55,66,12,34]
]
x=pd.DataFrame(student,columns=['marks','lpa','rollno','mathmrks','numberofst'])

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
dict={
    'name':['Nitish','amit','rahul','harsh'],
    'marks':[22,44,34,54]
}

# %%
y=pd.DataFrame(dict)

# %%
a=pd.read_csv('Test.csv')

# %%
a.set_index('ID')
# Out:
#         Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# ID
# 458989  Female          Yes   36       Yes       Engineer              0.0
# 458994    Male          Yes   37       Yes     Healthcare              8.0
# 458996  Female          Yes   69        No            NaN              0.0
# 459000    Male          Yes   59        No      Executive             11.0
# 459001  Female           No   19        No      Marketing              NaN
# ...        ...          ...  ...       ...            ...              ...
# 467954    Male           No   29        No     Healthcare              9.0
# 467958  Female           No   35       Yes         Doctor              1.0
# 467960  Female           No   53       Yes  Entertainment              NaN
# 467961    Male          Yes   47       Yes      Executive              1.0
# 467968  Female           No   43       Yes     Healthcare              9.0
#
#        Spending_Score  Family_Size  Var_1
# ID
# ...

# %%
a.index
# Out:
# RangeIndex(start=0, stop=2627, step=1)

# %%
a.shape
# Out:
# (2627, 10)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2627 entries, 0 to 2626
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2627 non-null   int64
#  1   Gender           2627 non-null   object
#  2   Ever_Married     2577 non-null   object
#  3   Age              2627 non-null   int64
#  4   Graduated        2603 non-null   object
#  5   Profession       2589 non-null   object
#  6   Work_Experience  2358 non-null   float64
#  7   Spending_Score   2627 non-null   object
#  8   Family_Size      2514 non-null   float64
#  9   Var_1            2595 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 205.4+ KB

# %%
a.describe()
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    2627.000000  2627.000000      2358.000000  2514.000000
# mean   463433.918919    43.649791         2.552587     2.825378
# std      2618.245698    16.967015         3.341094     1.551906
# min    458989.000000    18.000000         0.000000     1.000000
# 25%    461162.500000    30.000000         0.000000     2.000000
# 50%    463379.000000    41.000000         1.000000     2.000000
# 75%    465696.000000    53.000000         4.000000     4.000000
# max    467968.000000    89.000000        14.000000     9.000000

# %%
a.value_counts
# Out:
# <bound method DataFrame.value_counts of           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     458989  Female          Yes   36       Yes       Engineer
# 1     458994    Male          Yes   37       Yes     Healthcare
# 2     458996  Female          Yes   69        No            NaN
# 3     459000    Male          Yes   59        No      Executive
# 4     459001  Female           No   19        No      Marketing
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 0.0            Low          1.0  Cat_6
# ...

# %%
a.columns
# Out:
# Index(['ID', 'Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Var_1'],
#       dtype='object')

# %%
a.isnull()
# Out:
#          ID  Gender  Ever_Married    Age  Graduated  Profession  \
# 0     False   False         False  False      False       False
# 1     False   False         False  False      False       False
# 2     False   False         False  False      False        True
# 3     False   False         False  False      False       False
# 4     False   False         False  False      False       False
# ...     ...     ...           ...    ...        ...         ...
# 2622  False   False         False  False      False       False
# 2623  False   False         False  False      False       False
# 2624  False   False         False  False      False       False
# 2625  False   False         False  False      False       False
# 2626  False   False         False  False      False       False
#
#       Work_Experience  Spending_Score  Family_Size  Var_1
# 0               False           False        False  False
# 1               False           False        False  False
# ...

# %%
a.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married        50
# Age                  0
# Graduated           24
# Profession          38
# Work_Experience    269
# Spending_Score       0
# Family_Size        113
# Var_1               32
# dtype: int64

# %%
a.dtypes
# Out:
# ID                   int64
# Gender              object
# Ever_Married        object
# Age                  int64
# Graduated           object
# Profession          object
# Work_Experience    float64
# Spending_Score      object
# Family_Size        float64
# Var_1               object
# dtype: object

# %%
# a['ID'].dtypes='Int32'
a.head(12)
a.tail(12)
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 2615  467934  Female           No   42       Yes         Artist
# 2616  467938    Male          Yes   46       Yes  Entertainment
# 2617  467940  Female           No   27        No      Marketing
# 2618  467946  Female          Yes   42       Yes         Artist
# 2619  467948  Female           No   19        No     Healthcare
# 2620  467949    Male           No   21        No     Healthcare
# 2621  467950  Female           No   35       Yes  Entertainment
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 2615              0.0            Low          1.0  Cat_6
# ...

# %%
a.values
# Out:
# array([[458989, 'Female', 'Yes', ..., 'Low', 1.0, 'Cat_6'],
#        [458994, 'Male', 'Yes', ..., 'Average', 4.0, 'Cat_6'],
#        [458996, 'Female', 'Yes', ..., 'Low', 1.0, 'Cat_6'],
#        ...,
#        [467960, 'Female', 'No', ..., 'Low', 2.0, 'Cat_6'],
#        [467961, 'Male', 'Yes', ..., 'High', 5.0, 'Cat_4'],
#        [467968, 'Female', 'No', ..., 'Low', 3.0, 'Cat_7']], dtype=object)

# %%
# a.duplicate()
a[a.duplicated()]
a.duplicated()
a.duplicated().sum()
# Out:
# np.int64(0)

# %%
# a.rename(columns={['Ever_Married':'Married']}
a.rename(columns={'Ever_Married':'Married'},inplace=True)

# %%
a
# Out:
#           ID  Gender Married  Age Graduated     Profession  Work_Experience  \
# 0     458989  Female     Yes   36       Yes       Engineer              0.0
# 1     458994    Male     Yes   37       Yes     Healthcare              8.0
# 2     458996  Female     Yes   69        No            NaN              0.0
# 3     459000    Male     Yes   59        No      Executive             11.0
# 4     459001  Female      No   19        No      Marketing              NaN
# ...      ...     ...     ...  ...       ...            ...              ...
# 2622  467954    Male      No   29        No     Healthcare              9.0
# 2623  467958  Female      No   35       Yes         Doctor              1.0
# 2624  467960  Female      No   53       Yes  Entertainment              NaN
# 2625  467961    Male     Yes   47       Yes      Executive              1.0
# 2626  467968  Female      No   43       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1
# ...

# %%
a.rename(index={2622:'a'})
# Out:
#           ID  Gender Married  Age Graduated     Profession  Work_Experience  \
# 0     458989  Female     Yes   36       Yes       Engineer              0.0
# 1     458994    Male     Yes   37       Yes     Healthcare              8.0
# 2     458996  Female     Yes   69        No            NaN              0.0
# 3     459000    Male     Yes   59        No      Executive             11.0
# 4     459001  Female      No   19        No      Marketing              NaN
# ...      ...     ...     ...  ...       ...            ...              ...
# a     467954    Male      No   29        No     Healthcare              9.0
# 2623  467958  Female      No   35       Yes         Doctor              1.0
# 2624  467960  Female      No   53       Yes  Entertainment              NaN
# 2625  467961    Male     Yes   47       Yes      Executive              1.0
# 2626  467968  Female      No   43       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1
# ...

# %%
x.sum()
x.sum(axis=1)
print(x.mean())
print(x.std())
print(x.var())
print(x.max())
print(x.min(axis=1))
print(x.median())
# Out:
# marks         61.333333
# lpa           40.666667
# rollno        48.333333
# mathmrks      45.000000
# numberofst    37.333333
# dtype: float64
# marks         34.428670
# lpa           16.258331
# rollno        16.258331
# mathmrks      29.103264
# numberofst    39.106692
# dtype: float64
# marks         1185.333333
# lpa            264.333333
# rollno         264.333333
# mathmrks       847.000000
# numberofst    1529.333333
# dtype: float64
# marks         100
# lpa            55
# rollno         66
# mathmrks       67
# numberofst     78
# dtype: int64
# 0     0
# 1    34
# 2    12
# dtype: int64
# marks         50.0
# lpa           44.0
# rollno        45.0
# mathmrks      56.0
# numberofst    34.0
# dtype: float64

# %%
# a.str().sum()
a['ID']
a[0:2]
a[0::2]
# a[:2,:2:]
type(a['ID'])
a[['ID','Graduated']]
# a[[2,4,8]]
# Out:
#           ID Graduated
# 0     458989       Yes
# 1     458994       Yes
# 2     458996        No
# 3     459000        No
# 4     459001        No
# ...      ...       ...
# 2622  467954        No
# 2623  467958       Yes
# 2624  467960       Yes
# 2625  467961       Yes
# 2626  467968       Yes
#
# [2627 rows x 2 columns]

# %%
a.iloc[2]
# Out:
# ID                 458996
# Gender             Female
# Married               Yes
# Age                    69
# Graduated              No
# Profession            NaN
# Work_Experience       0.0
# Spending_Score        Low
# Family_Size           1.0
# Var_1               Cat_6
# Name: 2, dtype: object

# %%
a.iloc[2:2,]
a.iloc[2:9:1]
# a.iloc[,2:9:1]
a.iloc[[2,4,5,6]]
y
y.set_index('name')
# Out:
#         marks
# name
# Nitish     22
# amit       44
# rahul      34
# harsh      54

# %%
# y.set_index('name')
# y.loc(nitish)
# y.loc['Nitish']
y.loc['Nitish':'harsh']
y.loc[['Nitish','harsh']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[229], line 5
#       1 # y.set_index('name')
#       2 # y.loc(nitish)
#       3 # y.loc['Nitish']
#       4 y.loc['Nitish':'harsh']
# ----> 5 y.loc[['Nitish','harsh']]
#
# File /opt/anaconda3/envs/pytorch_m1/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/anaconda3/envs/pytorch_m1/lib/python3.10/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# ...

# %%
a.iloc[0:3,0:3]
# Out:
#        ID  Gender Married
# 0  458989  Female     Yes
# 1  458994    Male     Yes
# 2  458996  Female     Yes

# %%
a['name']='amit'

# %%
a
# Out:
#           ID  Gender Married  Age Graduated     Profession  Work_Experience  \
# 0     458989  Female     Yes   36       Yes       Engineer              0.0
# 1     458994    Male     Yes   37       Yes     Healthcare              8.0
# 2     458996  Female     Yes   69        No            NaN              0.0
# 3     459000    Male     Yes   59        No      Executive             11.0
# 4     459001  Female      No   19        No      Marketing              NaN
# ...      ...     ...     ...  ...       ...            ...              ...
# 2622  467954    Male      No   29        No     Healthcare              9.0
# 2623  467958  Female      No   35       Yes         Doctor              1.0
# 2624  467960  Female      No   53       Yes  Entertainment              NaN
# 2625  467961    Male     Yes   47       Yes      Executive              1.0
# 2626  467968  Female      No   43       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1  name
# ...

# %%
a['ID'].astype('int32')
# Out:
# 0       458989
# 1       458994
# 2       458996
# 3       459000
# 4       459001
#          ...
# 2622    467954
# 2623    467958
# 2624    467960
# 2625    467961
# 2626    467968
# Name: ID, Length: 2627, dtype: int32

# %%
a.value_counts()
# Out:
# ID      Gender  Married  Age  Graduated  Profession  Work_Experience  Spending_Score  Family_Size  Var_1  name
# 458989  Female  Yes      36   Yes        Engineer    0.0              Low             1.0          Cat_6  amit    1
# 464990  Male    Yes      73   No         Executive   0.0              High            2.0          Cat_6  amit    1
# 465040  Male    Yes      69   No         Lawyer      1.0              Average         2.0          Cat_6  amit    1
# 465039  Female  Yes      87   No         Lawyer      0.0              High            2.0          Cat_6  amit    1
# 465038  Male    Yes      49   No         Executive   0.0              High            4.0          Cat_6  amit    1
#                                                                                                                  ..
# 462007  Female  Yes      42   Yes        Artist      1.0              Average         2.0          Cat_6  amit    1
# ...

# %%
y.value_counts()
# Out:
# name    marks
# Nitish  22       1
# amit    44       1
# harsh   54       1
# rahul   34       1
# Name: count, dtype: int64

# %%
x.value_counts()
# Out:
# marks  lpa  rollno  mathmrks  numberofst
# 34     55   66      12        34            1
# 50     44   34      56        78            1
# 100    23   45      67        0             1
# Name: count, dtype: int64

# %%
a['ID'].isdigit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mx/zj8ldfqx7hn8ykwf8cfgz9sw0000gn/T/ipykernel_1366/4125927935.py in ?()
# ----> 1 a['ID'].isdigit()
#
# /opt/anaconda3/envs/pytorch_m1/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'isdigit'

# %%
a['Married'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
a.sort_values(by='ID',ascending=False)
a.sort_values(by='Age')
a.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Married             50
# Age                  0
# Graduated           24
# Profession          38
# Work_Experience    269
# Spending_Score       0
# Family_Size        113
# Var_1               32
# name                 0
# dtype: int64

# %%
a.sort_values(by='Married',na_position='first')
# Out:
#           ID  Gender Married  Age Graduated     Profession  Work_Experience  \
# 178   459516  Female     NaN   56       Yes         Artist              NaN
# 227   459699  Female     NaN   56       Yes       Engineer              8.0
# 240   459746    Male     NaN   59       Yes         Artist              1.0
# 248   459771  Female     NaN   30       Yes         Doctor              0.0
# 261   459821    Male     NaN   71        No      Executive              NaN
# ...      ...     ...     ...  ...       ...            ...              ...
# 1135  462788    Male     Yes   47        No  Entertainment              1.0
# 1134  462785  Female     Yes   42       Yes       Engineer              NaN
# 1133  462776  Female     Yes   52       Yes       Engineer              1.0
# 1149  462838  Female     Yes   33       Yes      Homemaker              1.0
# 1308  463368  Female     Yes   38       Yes         Artist              4.0
#
#      Spending_Score  Family_Size  Var_1  name
# ...

# %%
a.sort_values(by=['Married','Work_Experience'],ascending=[True,False])
# Out:
#           ID  Gender Married  Age Graduated     Profession  Work_Experience  \
# 402   460310    Male      No   27        No     Healthcare             14.0
# 403   460315  Female      No   35        No         Doctor             14.0
# 432   460388  Female      No   43       Yes         Artist             14.0
# 994   462297  Female      No   31       Yes         Artist             14.0
# 1104  462687    Male      No   26        No      Homemaker             14.0
# ...      ...     ...     ...  ...       ...            ...              ...
# 261   459821    Male     NaN   71        No      Executive              NaN
# 469   460504    Male     NaN   39        No      Executive              NaN
# 1736  464905    Male     NaN   81        No      Executive              NaN
# 2061  466032    Male     NaN   28        No  Entertainment              NaN
# 2286  466795    Male     NaN   60       Yes  Entertainment              NaN
#
#      Spending_Score  Family_Size  Var_1  name
# ...

# %%
a.rank()
# Out:
#           ID  Gender  Married     Age  Graduated  Profession  Work_Experience  \
# 0        1.0   602.0   1817.5   973.5     1802.5      1162.5            385.0
# 1        2.0  1915.5   1817.5  1042.5     1802.5      1966.5           2076.0
# 2        3.0   602.0   1817.5  2360.0      501.0         NaN            385.0
# 3        4.0  1915.5   1817.5  2126.0      501.0      1669.5           2307.5
# 4        5.0   602.0    529.0    67.5      501.0      2534.0              NaN
# ...      ...     ...      ...     ...        ...         ...              ...
# 2622  2623.0  1915.5    529.0   569.0      501.0      1966.5           2220.0
# 2623  2624.0   602.0    529.0   904.0     1802.5       923.5           1156.0
# 2624  2625.0   602.0    529.0  1987.0     1802.5      1431.0              NaN
# 2625  2626.0  1915.5   1817.5  1671.5     1802.5      1669.5           1156.0
# 2626  2627.0   602.0    529.0  1489.0     1802.5      1966.5           2220.0
#
# ...

# %%
a.rank
# Out:
# <bound method NDFrame.rank of           ID  Gender Married  Age Graduated     Profession  Work_Experience  \
# 0     458989  Female     Yes   36       Yes       Engineer              0.0
# 1     458994    Male     Yes   37       Yes     Healthcare              8.0
# 2     458996  Female     Yes   69        No            NaN              0.0
# 3     459000    Male     Yes   59        No      Executive             11.0
# 4     459001  Female      No   19        No      Marketing              NaN
# ...      ...     ...     ...  ...       ...            ...              ...
# 2622  467954    Male      No   29        No     Healthcare              9.0
# 2623  467958  Female      No   35       Yes         Doctor              1.0
# 2624  467960  Female      No   53       Yes  Entertainment              NaN
# 2625  467961    Male     Yes   47       Yes      Executive              1.0
# 2626  467968  Female      No   43       Yes     Healthcare              9.0
#
# ...

# %%
a['Work_Experience'].rank()
a.sort_index()
a.set_index('Age')
a.reset_index()
a.rename(columns={'Work_Experience':'Experience'})
P=a['ID']
P.unique()
len(P.unique())
P.nunique()
# Out:
# 2627

# %%
a['Married'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2622    True
# 2623    True
# 2624    True
# 2625    True
# 2626    True
# Name: Married, Length: 2627, dtype: bool

# %%
a['Married'].hasnans
# Out:
# True

# %%
a['Married'].dropna()
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 2622     No
# 2623     No
# 2624     No
# 2625    Yes
# 2626     No
# Name: Married, Length: 2577, dtype: object

# %%
a['Married'].dropna(how='all')
a['Married'].dropna(how='any')
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 2622     No
# 2623     No
# 2624     No
# 2625    Yes
# 2626     No
# Name: Married, Length: 2577, dtype: object

# %%
a.dropna(subset=['name','Age'])
# Out:
#           ID  Gender Married  Age Graduated     Profession  Work_Experience  \
# 0     458989  Female     Yes   36       Yes       Engineer              0.0
# 1     458994    Male     Yes   37       Yes     Healthcare              8.0
# 2     458996  Female     Yes   69        No            NaN              0.0
# 3     459000    Male     Yes   59        No      Executive             11.0
# 4     459001  Female      No   19        No      Marketing              NaN
# ...      ...     ...     ...  ...       ...            ...              ...
# 2622  467954    Male      No   29        No     Healthcare              9.0
# 2623  467958  Female      No   35       Yes         Doctor              1.0
# 2624  467960  Female      No   53       Yes  Entertainment              NaN
# 2625  467961    Male     Yes   47       Yes      Executive              1.0
# 2626  467968  Female      No   43       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1  name
# ...

# %%
a['Married'].fillna('unkknown')
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 2622     No
# 2623     No
# 2624     No
# 2625    Yes
# 2626     No
# Name: Married, Length: 2627, dtype: object

# %%
a.fillna(0)
# Out:
#           ID  Gender Married  Age Graduated     Profession  Work_Experience  \
# 0     458989  Female     Yes   36       Yes       Engineer              0.0
# 1     458994    Male     Yes   37       Yes     Healthcare              8.0
# 2     458996  Female     Yes   69        No              0              0.0
# 3     459000    Male     Yes   59        No      Executive             11.0
# 4     459001  Female      No   19        No      Marketing              0.0
# ...      ...     ...     ...  ...       ...            ...              ...
# 2622  467954    Male      No   29        No     Healthcare              9.0
# 2623  467958  Female      No   35       Yes         Doctor              1.0
# 2624  467960  Female      No   53       Yes  Entertainment              0.0
# 2625  467961    Male     Yes   47       Yes      Executive              1.0
# 2626  467968  Female      No   43       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1  name
# ...

# %%
a['Married'].fillna(a['Married'].mode())
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 2622     No
# 2623     No
# 2624     No
# 2625    Yes
# 2626     No
# Name: Married, Length: 2627, dtype: object

# %%
a.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2622    False
# 2623    False
# 2624    False
# 2625    False
# 2626    False
# Length: 2627, dtype: bool

# %%
b=pd.Series([2,3,4,5,6,7,8,8,8])
b.drop_duplicates()
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# 6    8
# dtype: int64

# %%
y.drop_duplicates()
# Out:
#      name  marks
# 0  Nitish     22
# 1    amit     44
# 2   rahul     34
# 3   harsh     54

# %%
y.drop_duplicates(keep='last')
# Out:
#      name  marks
# 0  Nitish     22
# 1    amit     44
# 2   rahul     34
# 3   harsh     54

# %%
b.drop(index=[0,2])
# Out:
# 1    3
# 3    5
# 4    6
# 5    7
# 6    8
# 7    8
# 8    8
# dtype: int64

# %%
a.drop(columns=['Age'])
# Out:
#           ID  Gender Married Graduated     Profession  Work_Experience  \
# 0     458989  Female     Yes       Yes       Engineer              0.0
# 1     458994    Male     Yes       Yes     Healthcare              8.0
# 2     458996  Female     Yes        No            NaN              0.0
# 3     459000    Male     Yes        No      Executive             11.0
# 4     459001  Female      No        No      Marketing              NaN
# ...      ...     ...     ...       ...            ...              ...
# 2622  467954    Male      No        No     Healthcare              9.0
# 2623  467958  Female      No       Yes         Doctor              1.0
# 2624  467960  Female      No       Yes  Entertainment              NaN
# 2625  467961    Male     Yes       Yes      Executive              1.0
# 2626  467968  Female      No       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1  name
# 0               Low          1.0  Cat_6  amit
# ...

# %%
c=pd.Series([4,90,80,77])

# %%
def sqaure(value):
    return value*value

# %%
c.apply(sqaure)
# Out:
# 0      16
# 1    8100
# 2    6400
# 3    5929
# dtype: int64

# %% [markdown]
# <h1> important function for the data science </h1>
# <h2><b>value_counts,sort_values,rank,sort_index,rename index,reset index,unique,nunique,isnull,notnull,hasnans,dropna,fillna,drop</h2>
