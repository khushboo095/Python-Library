# %%
import pandas as pd
import numpy as np

# %%
x=pd.Series(['akriti','pihu','ankita','prity'])
type(x)
x.str.startswith("a")
x.str.endswith("a")
len(x)
# Out:
# 4

# %%
df=pd.read_csv('cars.csv')

# %%
type(df)
df
# Out:
#         brand  km_driven    fuel                 owner  selling_price
# 0      Maruti     145500  Diesel           First Owner         450000
# 1       Skoda     120000  Diesel          Second Owner         370000
# 2       Honda     140000  Petrol           Third Owner         158000
# 3     Hyundai     127000  Diesel           First Owner         225000
# 4      Maruti     120000  Petrol           First Owner         130000
# ...       ...        ...     ...                   ...            ...
# 8123  Hyundai     110000  Petrol           First Owner         320000
# 8124  Hyundai     119000  Diesel  Fourth & Above Owner         135000
# 8125   Maruti     120000  Diesel           First Owner         382000
# 8126     Tata      25000  Diesel           First Owner         290000
# 8127     Tata      25000  Diesel           First Owner         290000
#
# [8128 rows x 5 columns]

# %%
df['brand'].str.lower()
# Out:
# 0        maruti
# 1         skoda
# 2         honda
# 3       hyundai
# 4        maruti
#          ...
# 8123    hyundai
# 8124    hyundai
# 8125     maruti
# 8126       tata
# 8127       tata
# Name: brand, Length: 8128, dtype: object

# %%
x.str.lower()
# Out:
# 0    akriti
# 1      pihu
# 2    ankita
# 3     prity
# dtype: object

# %%
x.str.upper()
x.str.capitalize()
# Out:
# 0    Akriti
# 1      Pihu
# 2    Ankita
# 3     Prity
# dtype: object

# %%
df['brand'].str.strip()
# Out:
# 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 8123    Hyundai
# 8124    Hyundai
# 8125     Maruti
# 8126       Tata
# 8127       Tata
# Name: brand, Length: 8128, dtype: object

# %%
df['brand'].str.title()
# Out:
# 0        Maruti
# 1         Skoda
# 2         Honda
# 3       Hyundai
# 4        Maruti
#          ...
# 8123    Hyundai
# 8124    Hyundai
# 8125     Maruti
# 8126       Tata
# 8127       Tata
# Name: brand, Length: 8128, dtype: object

# %%
df['brand'].str.len()
df['brand'].str.len().sum()
# Out:
# np.int64(50259)

# %%
[df['brand'].str.len()==50]
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  8123    False
#  8124    False
#  8125    False
#  8126    False
#  8127    False
#  Name: brand, Length: 8128, dtype: bool]

# %%
# df['brand'][df['brand'].str.len()==50].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['brand'][df['brand'].str.len()==50].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df['brand'][df['brand'].str.len()==50]
# Out:
# Series([], Name: brand, dtype: object)

# %%
# df['owner'][df['owner'].str.split('')]
# df['owner'].str.split('')
# Out:
# 0                   [, F, i, r, s, t,  , O, w, n, e, r, ]
# 1                [, S, e, c, o, n, d,  , O, w, n, e, r, ]
# 2                   [, T, h, i, r, d,  , O, w, n, e, r, ]
# 3                   [, F, i, r, s, t,  , O, w, n, e, r, ]
# 4                   [, F, i, r, s, t,  , O, w, n, e, r, ]
#                               ...
# 8123                [, F, i, r, s, t,  , O, w, n, e, r, ]
# 8124    [, F, o, u, r, t, h,  , &,  , A, b, o, v, e,  ...
# 8125                [, F, i, r, s, t,  , O, w, n, e, r, ]
# 8126                [, F, i, r, s, t,  , O, w, n, e, r, ]
# 8127                [, F, i, r, s, t,  , O, w, n, e, r, ]
# Name: owner, Length: 8128, dtype: object

# %%
df=pd.read_csv('data_science_job.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['enrolled_university'].str.split('_')
# Out:
# 0          [no, enrollment]
# 1          [no, enrollment]
# 2        [Full time course]
# 3                       NaN
# 4          [no, enrollment]
#                 ...
# 19153      [no, enrollment]
# 19154      [no, enrollment]
# 19155      [no, enrollment]
# 19156      [no, enrollment]
# 19157      [no, enrollment]
# Name: enrolled_university, Length: 19158, dtype: object

# %%
df['enrolled_university'].str.get(0)
# Out:
# 0          n
# 1          n
# 2          F
# 3        NaN
# 4          n
#         ...
# 19153      n
# 19154      n
# 19155      n
# 19156      n
# 19157      n
# Name: enrolled_university, Length: 19158, dtype: object

# %%
df['enrolled_university'].str.split('_').get(0)
# Out:
# ['no', 'enrollment']

# %%
df['enrolled_university'].str.split('_').str.get(0)
# Out:
# 0                      no
# 1                      no
# 2        Full time course
# 3                     NaN
# 4                      no
#                ...
# 19153                  no
# 19154                  no
# 19155                  no
# 19156                  no
# 19157                  no
# Name: enrolled_university, Length: 19158, dtype: object

# %%
df['company_size'].str.split('-',expand=True)
df['company_size'].str.split('-',n=2,expand=True)
df[['a','b']]=df['company_size'].str.split('-',expand=True)

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['a'].value_counts()
# Out:
# a
# 50        3083
# 100       2571
# 10000+    2019
# 10/49     1471
# 1000      1328
# <10       1308
# 500        877
# 5000       563
# Name: count, dtype: int64

# %%
df['a']=df['a'].str.replace('50','40')

# %%
df['a'].value_counts()
# Out:
# a
# 40        3083
# 100       2571
# 10000+    2019
# 10/49     1471
# 1000      1328
# <10       1308
# 400        877
# 4000       563
# Name: count, dtype: int64

# %%
df['relevent_experience'][df['relevent_experience'].str.startswith('No')]
# Out:
# 1        No relevent experience
# 2        No relevent experience
# 3        No relevent experience
# 10       No relevent experience
# 13       No relevent experience
#                   ...
# 19145    No relevent experience
# 19147    No relevent experience
# 19151    No relevent experience
# 19153    No relevent experience
# 19157    No relevent experience
# Name: relevent_experience, Length: 5366, dtype: object

# %%
df[df['relevent_experience'].str.startswith('No')]
# Out:
#        enrollee_id      city  city_development_index gender  \
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 10           29452   city_21                   0.624    NaN
# 13            5826   city_21                   0.624   Male
# ...            ...       ...                     ...    ...
# 19145          155   city_44                   0.725    NaN
# 19147        21319   city_21                   0.624   Male
# 19151        11385  city_149                   0.689   Male
# 19153         7386  city_173                   0.878   Male
# 19157        23834   city_67                   0.855    NaN
#
#           relevent_experience enrolled_university education_level  \
# 1      No relevent experience       no_enrollment        Graduate
# 2      No relevent experience    Full time course        Graduate
# ...

# %%
df[df['city'].str.isdigit()]
# Out:
# Empty DataFrame
# Columns: [enrollee_id, city, city_development_index, gender, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, training_hours, target, a, b]
# Index: []

# %%
# df[df['experience'].str.isdigit()]
df['experience'].str.isdigit()
df['a'].str.isdigit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 2
#       1 # df[df['experience'].str.isdigit()]
# ----> 2 df['experience'].str.isdigit()
#       3 df['a'].str.isdigit()
#
# File /opt/anaconda3/envs/pytorch_m1/lib/python3.10/site-packages/pandas/core/generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# File /opt/anaconda3/envs/pytorch_m1/lib/python3.10/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df['gender'].str.contains('male',case=False)
# Out:
# 0        True
# 1        True
# 2         NaN
# 3         NaN
# 4        True
#          ...
# 19153    True
# 19154    True
# 19155    True
# 19156    True
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %%
df['gender'].str.contains('^[aeiouAEIOU].+[aeiouAEIOU]$]')
# Out:
# 0        False
# 1        False
# 2          NaN
# 3          NaN
# 4        False
#          ...
# 19153    False
# 19154    False
# 19155    False
# 19156    False
# 19157      NaN
# Name: gender, Length: 19158, dtype: object

# %%
df['city'].str[:]
df['city'].str[:1]
# Out:
# 0        c
# 1        c
# 2        c
# 3        c
# 4        c
#         ..
# 19153    c
# 19154    c
# 19155    c
# 19156    c
# 19157    c
# Name: city, Length: 19158, dtype: object

# %%
df['city'].str[::-1]
# Out:
# 0        301_ytic
# 1         04_ytic
# 2         12_ytic
# 3        511_ytic
# 4        261_ytic
#            ...
# 19153    371_ytic
# 19154    301_ytic
# 19155    301_ytic
# 19156     56_ytic
# 19157     76_ytic
# Name: city, Length: 19158, dtype: object

# %%
df['city'].str[::2]
# Out:
# 0        ct_0
# 1        ct_0
# 2        ct_1
# 3        ct_1
# 4        ct_6
#          ...
# 19153    ct_7
# 19154    ct_0
# 19155    ct_0
# 19156    ct_5
# 19157    ct_7
# Name: city, Length: 19158, dtype: object

# %%
df.str[::2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mx/zj8ldfqx7hn8ykwf8cfgz9sw0000gn/T/ipykernel_1533/1331912457.py in ?()
# ----> 1 df.str[::2]
#
# /opt/anaconda3/envs/pytorch_m1/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'
